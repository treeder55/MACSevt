# %%
#!jt -t chesterish -T -N -fs 120 -altp -tfs 14 -nfs 115 -cellw 98% -T

# %%
# package imports, alt+f to fold
import os
import shutil
import numpy as np
import scipy as sp 
import struct
import glob
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from EventStreamParse_class_BSacc import *  #histogram package
from evtParsefunctions import *
import BSacc2 as bsa
import TRplot as trp
from lmfit import models
from lmfit import Model
# %load_ext memory_profiler

# %%
# %%time
lowang =  -11-92+10.947  # low angle for basesampletheta
highang =  -11+92+10.947  # high angle for basesampletheta
tbins = 200   # number of bins in time direction
BSbins = 1000   # number of bins in basesamplethetadirection
offset = 118.0575 #  offset = A3 - kidney - basesampletheta
tpulse = 41
BSlpulse = 48
BShpulse = 47
tstepforcoverage = 20/tbins/50
#omega = 2.95167
omega = np.average([2.95098,2.95197,2.95209,2.95139])
dirr = './HTO_20190403/fpx95100/'
evt = dirr+'evt/'
rg0dir = './Reduced_04302020/rg0_04302020/'
rottime = 62.92671329475*2
pulsewidth = 20.00041688779221
fpx = 'fpx95100'
#args = [evt,pulsewidth,lowang,highang,tbins,BSbins,offset,fpx,tpulse,BSlpulse,BShpulse,rottime]
args = [evt,lowang,highang,BSbins,offset,fpx,BSlpulse,BShpulse,rottime,tstepforcoverage,omega]
hist = MACS_BS(args)
#hist.histogram()
#hist.saveduphistasrg0(rg0dir,pulsewidth,tbins)

# %%
# %%time
lowang =  -11-92+10.947  # low angle for basesampletheta
highang =  -11+92+10.947  # high angle for basesampletheta
tbins = 200   # number of bins in time deriction
BSbins = 1000   # number of bins in basesamplethetadirection
offset = -27.1493 #  offset = A3 - kidney - basesampletheta
tpulse = 41
BSlpulse = 48
BShpulse = 47
tstepforcoverage = 20/tbins/50
omega = np.average([2.95912, 2.95440, 2.95098, 2.956208])
dirr = './HTO_20190403/fpx95033/'
evt = dirr+'evt/'
rg0dir = './Reduced_04302020/rg0_04302020/'
rottime = 62.92671329475*2
pulsewidth = 20.00041688779221
fpx = 'fpx95033'
#args = [evt,pulsewidth,lowang,highang,tbins,BSbins,offset,fpx,tpulse,BSlpulse,BShpulse,rottime]
args = [evt,lowang,highang,BSbins,offset,fpx,BSlpulse,BShpulse,rottime,tstepforcoverage,omega]
hist = MACS_BS(args)
#hist.histogram()
#hist.saveduphistasrg0(rg0dir,pulsewidth,tbins)

# %%
# %%time
lowang =  -11-92+10.947  # low angle for basesampletheta
highang =  -11+92+10.947  # high angle for basesampletheta
tbins = 200   # number of bins in time deriction
BSbins = 1000   # number of bins in basesamplethetadirection
tpulse = 2
BSlpulse = 4
BShpulse = 6
tstepforcoverage = 20/tbins/50
offset = -26.345 #  offset = A3 - kidney - basesampletheta
pulsewidth = 20.00041688779221
rottime = 62.926203749999985*2
dirr = './HTO_20190322/All3amp/'
rg0dir = './Reduced_04302020/rg0_04302020/'
drg0dir = './Reduced_04302020/rg0_last8seconds_04302020/'

omega = np.average([2.95647, 2.95350, 2.95668, 2.95581])
#fpx = 'fpx94703'
#evt = dirr+'fpx94703/evt/oddevt/'
#args = [evt,pulsewidth,lowang,highang,tbins,BSbins,offset,fpx,tpulse,BSlpulse,BShpulse,rottime,tstepforcoverage,omega]
#hist = MACS_BS_t(args)
##hist.savehistasrg0(rg0dir)
##hist.savepartialtimeasrg0(drg0dir,12,20)

fpx = 'fpx94711'
evt = dirr+'fpx94703/evt/evenevt/'
args = [evt,pulsewidth,lowang,highang,tbins,BSbins,offset,fpx,tpulse,BSlpulse,BShpulse,rottime,tstepforcoverage,omega]
hist = MACS_BS_t(args)
#hist.savehistasrg0(rg0dir)
#hist.savepartialtimeasrg0(drg0dir,12,20)

#omega = np.average([2.954575, 2.953075, 2.954752, 2.953955])
#fpx = 'fpx94727'
#evt = dirr+fpx+'/evt/'
#args = [evt,pulsewidth,lowang,highang,tbins,BSbins,offset,fpx,tpulse,BSlpulse,BShpulse,rottime,tstepforcoverage,omega]
#hist = MACS_BS_t(args)
##hist.savehistasrg0(rg0dir)
##hist.savepartialtimeasrg0(drg0dir,12,20)
#
#fpx = 'fpx94728'
#evt = dirr+fpx+'/evt/'
#args = [evt,pulsewidth,lowang,highang,tbins,BSbins,offset,fpx,tpulse,BSlpulse,BShpulse,rottime,tstepforcoverage,omega]
#hist = MACS_BS_t(args)
##hist.savehistasrg0(rg0dir)
##hist.savepartialtimeasrg0(drg0dir,12,20)
# Out:
# ./HTO_20190322/All3amp/fpx94703/evt/evenevt\201903260242.evt
# values/4 = 9853376.0
# length of raw_t = 12832845
# time of file = 5959.786143372
# missing l pulse: []
# missing h pulse: []
# missing t0 pulse: []
# double l pulse: []
# double h pulse: []
# double t0 pulse: []
# ./HTO_20190322/All3amp/fpx94703/evt/evenevt\201903260422.evt
# values/4 = 10788284.0
# length of raw_t = 13767872
# time of file = 5959.785539904
# missing l pulse: []
# missing h pulse: []
# missing t0 pulse: []
# double l pulse: []
# double h pulse: []
# double t0 pulse: [87]
# ./HTO_20190322/All3amp/fpx94703/evt/evenevt\201903260601.evt
# values/4 = 11383164.0
# length of raw_t = 14319757
# time of file = 5873.564374988
# missing l pulse: []
# missing h pulse: []
# missing t0 pulse: []
# double l pulse: []
# double h pulse: []
# double t0 pulse: [161]
# ./HTO_20190322/All3amp/fpx94703/evt/evenevt\201903260739.evt
# values/4 = 10878530.0
# length of raw_t = 13843635
# time of file = 5930.687036812
# ...

# %%
# %%time
lowang =  -11-92+10.947  # low angle for basesampletheta
highang =  -11+92+10.947  # high angle for basesampletheta
tbins = 200   # number of bins in time deriction
BSbins = 1000   # number of bins in basesamplethetadirection
offset = 118.0575 #  offset = A3 - kidney - basesampletheta
tpulse = 41
BSlpulse = 48
BShpulse = 47
tstepforcoverage = 20/tbins/50
omega = np.average([2.95098,2.95197,2.95209,2.95139])
pulsewidth = 20.00041688779221
rottime = 62.92668286495773*2
dirr = './HTO_20190403/fpx95088o_fpx95089e/'
rg0dir = './Reduced_04302020/rg0_04302020/'
drg0dir = './Reduced_04302020/rg0_last8seconds_04302020/'

evt = dirr+'odd/'
fpx = 'fpx95088'
args = [evt,pulsewidth,lowang,highang,tbins,BSbins,offset,fpx,tpulse,BSlpulse,BShpulse,rottime,tstepforcoverage,omega]
hist = MACS_BS_t(args)
#hist.savehistasrg0(rg0dir)
#hist.savepartialtimeasrg0(drg0dir,12,20)

evt = dirr+'even/'
fpx = 'fpx95089'
args = [evt,pulsewidth,lowang,highang,tbins,BSbins,offset,fpx,tpulse,BSlpulse,BShpulse,rottime,tstepforcoverage,omega]
hist = MACS_BS_t(args)
#hist.savehistasrg0(rg0dir)
#hist.savepartialtimeasrg0(drg0dir,12,20)

dirr = './HTO_20190403/fpx95098o_fpx95099e/'
pulsewidth = 20.000412931244583  # still have these as an input so we can use very short kidney scans that don't have more than one pulse.
rottime = 62.926690431480004*2

evt = dirr+'odd/'
fpx = 'fpx95098'
args = [evt,pulsewidth,lowang,highang,tbins,BSbins,offset,fpx,tpulse,BSlpulse,BShpulse,rottime,tstepforcoverage,omega]
hist = MACS_BS_t(args)
#hist.savehistasrg0(rg0dir)
#hist.savepartialtimeasrg0(drg0dir,12,20)

evt = dirr+'even/'
fpx = 'fpx95099'
args = [evt,pulsewidth,lowang,highang,tbins,BSbins,offset,fpx,tpulse,BSlpulse,BShpulse,rottime,tstepforcoverage,omega]
hist = MACS_BS_t(args)
#hist.savehistasrg0(rg0dir)
#hist.savepartialtimeasrg0(drg0dir,12,20)
# Out:
# ./HTO_20190403/fpx95088o_fpx95089e/odd\201904050739.evt
# values/4 = 6526104.0
# length of raw_t = 8849884
# time of file = 4648.243857154
# missing l pulse: []
# missing h pulse: []
# missing t0 pulse: []
# ./HTO_20190403/fpx95088o_fpx95089e/odd\201904050857.evt
# values/4 = 6929000.0
# length of raw_t = 9199045
# time of file = 4540.878060106
# missing l pulse: []
# missing h pulse: []
# missing t0 pulse: []
# ./HTO_20190403/fpx95088o_fpx95089e/odd\201904051013.evt
# values/4 = 7560046.0
# length of raw_t = 9821576
# time of file = 4524.281738466
# missing l pulse: []
# missing h pulse: []
# missing t0 pulse: []
# ./HTO_20190403/fpx95088o_fpx95089e/odd\201904051128.evt
# values/4 = 7233538.0
# length of raw_t = 9652125
# time of file = 4838.511789158
# missing l pulse: []
# missing h pulse: []
# missing t0 pulse: []
# ./HTO_20190403/fpx95088o_fpx95089e/odd\201904051249.evt
# values/4 = 7409636.0
# length of raw_t = 9630954
# time of file = 4443.15794135
# missing l pulse: []
# ...

# %%
hist.integratehistintime()

# %%
for i in range(25):
    trp.trplot(np.arange(len(hist.E[0][i])),hist.E[0][i],title=str(i))

# %%
i = 1
rt=np.average((hist.t_BSl[0][1:]-hist.t_BSl[0][:-1])/2)
#trp.trplot(np.linspace(0,184,len(hist.tE[0][i])),hist.tE[0][i])
trp.trplot(np.linspace(0,rt,len(hist.E[0][i])),hist.E[0][i],xlabel='time',ylabel='counts',labelcolor='dodgerblue')

# %%
hints = [2000,33,0.1,2000,57,0.1]
x = np.linspace(0,rt,len(hist.E[0][i]))
#x = np.linspace(0,184,len(hist.tE[0][2]))
y = hist.E[0][i]
result = trp.trfit2G(x,y,hints)
result.plot_fit()

# %%
#a = 109.47122
a = 70.52878
#a = 125.26429
print('predicted separation angle = '+str((result.params['two_center'].value-result.params['one_center'].value)*omega))
print('current omega = '+str(omega))
print('calculated omega = '+str(a/(result.params['two_center'].value-result.params['one_center'].value)))
print('predicted omega for next round = '+str(np.average([a/(result.params['two_center'].value-result.params['one_center'].value),omega])))
print('difference in angle = '+str(a-(result.params['two_center'].value-result.params['one_center'].value)*omega))
